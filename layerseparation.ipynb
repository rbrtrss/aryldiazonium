# %%
import numpy as np
import pandas as pd

# %%
e_mono = -62.17710485
e_mono211 = -124.22784273
e_ed = -72.72413690

# %%
two_bp = pd.read_csv('combined.dat', sep='  ', names=['d', 'E'])
two_bp = two_bp.sort_values(by='d')
two_bp['deltaE'] = two_bp['E']- (2* e_mono)
two_bp.plot(x='d', y='deltaE')
# Out:
# /tmp/ipykernel_5475/4259061193.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   two_bp = pd.read_csv('combined.dat', sep='  ', names=['d', 'E'])
# <AxesSubplot:xlabel='d'>

# %%
zoomed_two_bp = two_bp[two_bp['d'] > 2.7]
zoomed_two_bp.plot(x='d', y='deltaE')
# Out:
# <AxesSubplot:xlabel='d'>

# %%
bp_ed = pd.read_csv('bp_ed.dat', sep='  ', names=['d', 'E'])
bp_ed = bp_ed.sort_values(by='d')
bp_ed['deltaE'] = bp_ed['E'] - (e_mono211 + e_ed)
bp_ed.plot(x='d', y='deltaE')
# Out:
# /tmp/ipykernel_5475/150074537.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   bp_ed = pd.read_csv('bp_ed.dat', sep='  ', names=['d', 'E'])
# <AxesSubplot:xlabel='d'>

# %%
zoomed_bp_ed = bp_ed[bp_ed['d'] > 2.2]
zoomed_bp_ed.plot(x='d', y='deltaE')
# Out:
# <AxesSubplot:xlabel='d'>

# %%
sand = pd.read_csv('sand.dat', sep='  ', names=['d', 'E'])
sand = sand.sort_values(by='d')
sand['deltaE'] = sand['E'] - (e_ed + 2 * e_mono211)
sand.plot(x='d', y='deltaE')
# Out:
# /tmp/ipykernel_5475/1038553872.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   sand = pd.read_csv('sand.dat', sep='  ', names=['d', 'E'])
# <AxesSubplot:xlabel='d'>

# %%
sand['E'].idxmin()
# Out:
# 11

# %%
sand
# Out:
#        d           E    deltaE
# 0   2.00 -321.172913  0.006909
# 1   2.05 -321.185297 -0.005475
# 2   2.10 -321.195661 -0.015839
# 3   2.15 -321.204244 -0.024421
# 4   2.20 -321.211250 -0.031427
# 5   2.25 -321.216863 -0.037041
# 6   2.30 -321.221280 -0.041458
# 7   2.35 -321.224629 -0.044806
# 8   2.40 -321.227070 -0.047247
# 9   2.45 -321.228715 -0.048893
# 10  2.50 -321.229702 -0.049880
# 11  2.55 -321.230116 -0.050294
# 12  2.60 -321.230069 -0.050247
# 13  2.65 -321.229635 -0.049813
# 14  2.70 -321.228917 -0.049095
# 15  2.75 -321.227963 -0.048141
# 16  2.80 -321.226836 -0.047014
# 17  2.85 -321.225583 -0.045760
# 18  2.90 -321.224265 -0.044443
# 19  2.95 -321.222897 -0.043074
# 20  3.00 -321.221502 -0.041679
